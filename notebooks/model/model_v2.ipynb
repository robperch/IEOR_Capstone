# %% [markdown]
# # ML Models

# %% [markdown]
# # Imports

# %% [markdown]
# #### Standard library imports

# %%
import sys
import os
sys.path.append("../..")

# %% [markdown]
# #### Third party imports

# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_auc_score
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report

# %% [markdown]
# #### Local application imports

# %%
# %load_ext autoreload
# %autoreload 2

from pkg_dir.config import *
from pkg_dir.src.utils import *
from pkg_dir.src.functions import *
from pkg_dir.src.parameters import *

# %% [markdown]
# # Pickle Extraction

# %%
path = '../../pkg_dir/data/pickles'
name = 'dataset_v1.pkl'

## Reading extract object saved as pickle locally
pkl_obj = path + "/" + name

with open(pkl_obj, 'rb') as obj_content:
    df = pickle.load(obj_content)

# %%
df
# Out:
#          appointment_id  appointment_weekday   appointment_start  \
# 2       2021923564                         5 2022-01-22 12:30:00
# 3       2021853399                         0 2022-01-24 12:00:00
# 4       2021845947                         0 2022-01-31 13:00:00
# 5       2021924951                         1 2022-01-25 13:30:00
# 6       2021889374                         5 2022-01-22 08:00:00
# ...                 ...                  ...                 ...
# 544083  2022136584                         3 2022-12-29 10:00:00
# 544084  2022141229                         2 2022-11-30 08:30:00
# 544085  2022506277                         5 2022-06-25 10:00:00
# 544086  2023228381                         3 2023-01-05 08:30:00
# 544087  2023000312555                      1 2023-01-31 13:30:00
#
#         appointment_dur_min recurring_patient  creation_to_start_hrs  \
# 2                      30.0             first                  20.52
# 3                      30.0             first                  52.19
# 4                      30.0             first                 221.78
# 5                      30.0             first                  78.35
# 6                      30.0             first                  24.22
# ...                     ...               ...                    ...
# 544083                 30.0         recurrent                2181.63
# 544084                 30.0         recurrent                  14.12
# 544085                 30.0             first                  25.08
# 544086                 30.0         recurrent                  39.87
# 544087                 30.0               NaN               -8345.70
#
#         confirm_request_msg  patient_confirm  confirm_to_start_hrs  \
# 2                         0                0                   NaN
# 3                         0                0                   NaN
# 4                         0                0                   NaN
# 5                         0                0                   NaN
# 6                         0                1                 21.75
# ...                     ...              ...                   ...
# 544083                    1                1                 49.28
# 544084                    0                1                 14.05
# 544085                    0                1                 19.02
# 544086                    0                1                 15.32
# 544087                    0                0                   NaN
#
#                  clinic appointment_source appointment_date_update  \
# 2       MARINA NACIONAL              phone               no_update
# 3       MARINA NACIONAL              phone               no_update
# 4               TLALPAN              phone               no_update
# 5              BASILICA              phone               no_update
# 6              BASILICA              phone               no_update
# ...                 ...                ...                     ...
# 544083            COAPA              phone               no_update
# 544084            COAPA              phone               no_update
# 544085            COAPA              phone               no_update
# 544086            COAPA              phone               no_update
# 544087  MARINA NACIONAL             online               no_update
#
#         patient_age patient_sex                                  doctor  \
# 2              32.0           F     DR. ORLANDO JOSE HERNANDEZ MARTINEZ
# 3              32.0           F  DRA JUANA GUADALUPE CABALLERO MARTINEZ
# 4              32.0           F                   Mariana  Sarao Pineda
# 5              32.0           F        DRA ANA MARIA ESCOBEDO HERNANDEZ
# 6              40.0           F        DRA MONICA MARCELA MACIAS ORTEGA
# ...             ...         ...                                     ...
# 544083         60.0           M       DRA LAURA FABIOLA PORTILLO GARCIA
# 544084         33.0           M        DR. MIGUEL ANGEL MONTERO MARQUEZ
# 544085         33.0           M   DRA SANDRA XOCHIQUETZAL  CRUZ ORDOÑEZ
# 544086         33.0           M   DRA SANDRA XOCHIQUETZAL  CRUZ ORDOÑEZ
# 544087         25.0           F                   Mariana  Sarao Pineda
#
#            medical_specialty appointment_status_simplified
# 2                   UROLOGIA                        cancel
# 3                GINECOLOGIA                        cancel
# 4               DERMATOLOGIA                        cancel
# 5               DERMATOLOGIA                        cancel
# 6             ENDOCRINOLOGIA                     completed
# ...                      ...                           ...
# 544083            NEFROLOGIA                       no_show
# 544084  OTORRINOLARINGOLOGIA                     completed
# 544085              UROLOGIA                     completed
# 544086              UROLOGIA                       no_show
# 544087          DERMATOLOGIA                       no_show
#
# [386750 rows x 17 columns]

# %%
df['medical_specialty'].replace({'Ultrasonido': 'ULTRASONIDO'}, inplace = True)
rounded_times = pd.to_datetime(df['appointment_start']).dt.round('60min')
df['rounded_start_times'] = rounded_times.dt.strftime('%H:%M:%S')
df['confirm_to_start_hrs'].fillna(df['confirm_to_start_hrs'].mean(), inplace = True)
df.dropna(subset= ['recurring_patient', 'creation_to_start_hrs', 'patient_age', 'patient_sex'], inplace = True)
months = [m.strftime('%B') for m in df['appointment_start']]
df['month'] = months
# Mapping for days of the week
days_mapping = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}

# Mapping for 01 to 'no' and 'yes'
binary_mapping = {0: 'no', 1: 'yes'}

# Replace values in the DataFrame
df['appointment_weekday'] = df['appointment_weekday'].replace(days_mapping)
df['confirm_request_msg'] = df['confirm_request_msg'].replace(binary_mapping)
df['patient_confirm'] = df['patient_confirm'].replace(binary_mapping)

# %%
df.drop(columns = ['appointment_id', 'appointment_start', 'doctor'], inplace = True)

# %%
gynecology = df.loc[(df['medical_specialty'] == 'GINECOLOGIA') & (df['appointment_status_simplified'] != 'cancel')]
gynecology.drop(columns = 'medical_specialty', inplace = True)
# Out:
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/4078157007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ginecology.drop(columns = 'medical_specialty', inplace = True)

# %%
gynecology
# Out:
#        appointment_weekday  appointment_dur_min recurring_patient  \
# 13                  Monday                 30.0         recurrent
# 14                  Friday                 30.0         recurrent
# 20                Thursday                 30.0             first
# 24                Saturday                 30.0         recurrent
# 30                  Monday                 30.0             first
# ...                    ...                  ...               ...
# 544052              Friday                 60.0             first
# 544064              Friday                 30.0             first
# 544072            Saturday                 30.0             first
# 544074              Friday                 60.0             first
# 544075              Friday                 30.0         recurrent
#
#         creation_to_start_hrs confirm_request_msg patient_confirm  \
# 13                      92.60                  no             yes
# 14                     150.96                 yes             yes
# 20                     127.04                  no             yes
# 24                     167.85                 yes             yes
# 30                      99.54                  no             yes
# ...                       ...                 ...             ...
# 544052                  30.73                  no             yes
# 544064                  17.62                  no             yes
# 544072                   2.96                  no             yes
# 544074                  73.80                  no             yes
# 544075                 331.84                  no             yes
#
#         confirm_to_start_hrs      clinic appointment_source  \
# 13                     50.21     TLALPAN              phone
# 14                     21.90       COAPA              phone
# 20                      8.13     TLALPAN              phone
# 24                     17.63       COAPA              phone
# 30                     67.97     TLALPAN              phone
# ...                      ...         ...                ...
# 544052                 -0.13    BASILICA              phone
# 544064                 17.62       COAPA              phone
# 544072                  2.96  CUAJIMALPA              phone
# 544074                 55.52       COAPA              phone
# 544075                 23.32       COAPA              phone
#
#        appointment_date_update  patient_age patient_sex  \
# 13                   no_update         39.0           F
# 14                   no_update         26.0           F
# 20                   no_update         38.0           F
# 24                   no_update         25.0           F
# 30                   no_update         24.0           F
# ...                        ...          ...         ...
# 544052               no_update         32.0           F
# 544064               no_update         24.0           F
# 544072               no_update         41.0           F
# 544074               no_update         68.0           F
# 544075               no_update         68.0           F
#
#        appointment_status_simplified rounded_start_times     month
# 13                         completed            11:00:00   October
# 14                         completed            14:00:00   January
# 20                         completed            16:00:00   January
# 24                         completed            08:00:00   January
# 30                           no_show            14:00:00   October
# ...                              ...                 ...       ...
# 544052                     completed            16:00:00  December
# 544064                     completed            11:00:00  December
# 544072                     completed            12:00:00  December
# 544074                     completed            18:00:00  December
# 544075                     completed            14:00:00  December
#
# [45674 rows x 15 columns]

# %%
X = gynecology.drop(columns = ['appointment_status_simplified'])
y = gynecology['appointment_status_simplified']

# %%
X
# Out:
#        appointment_weekday  appointment_dur_min recurring_patient  \
# 13                  Monday                 30.0         recurrent
# 14                  Friday                 30.0         recurrent
# 20                Thursday                 30.0             first
# 24                Saturday                 30.0         recurrent
# 30                  Monday                 30.0             first
# ...                    ...                  ...               ...
# 544052              Friday                 60.0             first
# 544064              Friday                 30.0             first
# 544072            Saturday                 30.0             first
# 544074              Friday                 60.0             first
# 544075              Friday                 30.0         recurrent
#
#         creation_to_start_hrs confirm_request_msg patient_confirm  \
# 13                      92.60                  no             yes
# 14                     150.96                 yes             yes
# 20                     127.04                  no             yes
# 24                     167.85                 yes             yes
# 30                      99.54                  no             yes
# ...                       ...                 ...             ...
# 544052                  30.73                  no             yes
# 544064                  17.62                  no             yes
# 544072                   2.96                  no             yes
# 544074                  73.80                  no             yes
# 544075                 331.84                  no             yes
#
#         confirm_to_start_hrs      clinic appointment_source  \
# 13                     50.21     TLALPAN              phone
# 14                     21.90       COAPA              phone
# 20                      8.13     TLALPAN              phone
# 24                     17.63       COAPA              phone
# 30                     67.97     TLALPAN              phone
# ...                      ...         ...                ...
# 544052                 -0.13    BASILICA              phone
# 544064                 17.62       COAPA              phone
# 544072                  2.96  CUAJIMALPA              phone
# 544074                 55.52       COAPA              phone
# 544075                 23.32       COAPA              phone
#
#        appointment_date_update  patient_age patient_sex rounded_start_times  \
# 13                   no_update         39.0           F            11:00:00
# 14                   no_update         26.0           F            14:00:00
# 20                   no_update         38.0           F            16:00:00
# 24                   no_update         25.0           F            08:00:00
# 30                   no_update         24.0           F            14:00:00
# ...                        ...          ...         ...                 ...
# 544052               no_update         32.0           F            16:00:00
# 544064               no_update         24.0           F            11:00:00
# 544072               no_update         41.0           F            12:00:00
# 544074               no_update         68.0           F            18:00:00
# 544075               no_update         68.0           F            14:00:00
#
#            month
# 13       October
# 14       January
# 20       January
# 24       January
# 30       October
# ...          ...
# 544052  December
# 544064  December
# 544072  December
# 544074  December
# 544075  December
#
# [45674 rows x 14 columns]

# %%
X_train, X_test, y_train_old, y_test_old = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train_old)
y_test = le.fit_transform(y_test_old)

# %%
y_train_old, y_test_old
# Out:
# (534715    completed
#  489764      no_show
#  431058    completed
#  423963    completed
#  254814    completed
#              ...
#  260991      no_show
#  536224    completed
#  480435    completed
#  23308     completed
#  298046    completed
#  Name: appointment_status_simplified, Length: 34255, dtype: object,
#  358511      no_show
#  365145    completed
#  185609    completed
#  451336    completed
#  531616    completed
#              ...
#  238393    completed
#  253550    completed
#  326766    completed
#  382728    completed
#  481145    completed
#  Name: appointment_status_simplified, Length: 11419, dtype: object)

# %%
y_train, y_test
# Out:
# (array([0, 1, 0, ..., 0, 0, 0]), array([1, 0, 0, ..., 0, 0, 0]))

# %%
most_common_label = np.argmax(np.bincount(y_train))
baseline_1_acc = (y_test == most_common_label).mean()
baseline_1_acc
# Out:
# 0.8165338470969437

# %%
encoder = OneHotEncoder(handle_unknown="ignore")
encoder.fit(X_train)
X_train = encoder.transform(X_train)
X_test = encoder.transform(X_test)

# %%
model = LogisticRegression(class_weight='balanced')

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)

# %%
model_acc = accuracy_score(y_test, y_pred)
model_acc

# %%
coefficients = model.coef_[0]

# %%
for feature, coef in zip(X.columns, coefficients):
    print(f"{feature}: {coef}")
# Out:
# appointment_weekday: -0.05092829889355761
# appointment_dur_min: 0.01622074882145207
# recurring_patient: 0.10000658998745128
# creation_to_start_hrs: 0.11735631402600437
# confirm_request_msg: -0.09238978622880799
# patient_confirm: -0.08906982357384997
# confirm_to_start_hrs: -0.026894670811244383
# clinic: -0.06349030900106144
# appointment_source: -0.13132222759297607
# appointment_date_update: 0.9798180900418912
# patient_age: 0.34981457258312126
# patient_sex: -0.6037099736731184
# rounded_start_times: -0.6542011772801011
# month: -0.37068584555301415

# %%
most_significant_features = [feature for feature, coef in zip(X.columns, coefficients) if abs(coef) > 0.1]
print("Most significant features:", most_significant_features)
# Out:
# Most significant features: ['recurring_patient', 'creation_to_start_hrs', 'appointment_source', 'appointment_date_update', 'patient_age', 'patient_sex', 'rounded_start_times', 'month']

# %%
cm= confusion_matrix(y_test, y_pred)
accuracy = (cm.ravel()[0] + cm.ravel()[3]) / sum(cm.ravel())
TPR = cm.ravel()[3] / (cm.ravel()[2] + cm.ravel()[3])
FPR = cm.ravel()[1] / (cm.ravel()[0] + cm.ravel()[1])
print('accuracy: ', accuracy)
print('TPR: ', TPR)
print('FPR: ', FPR)
# Out:
# accuracy:  0.6762413521324109
# TPR:  0.3723150357995227
# FPR:  0.2554697554697555

# %%
print(classification_report(y_test, y_pred))
print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79      9324
#            1       0.25      0.37      0.30      2095
#
#     accuracy                           0.68     11419
#    macro avg       0.54      0.56      0.54     11419
# weighted avg       0.73      0.68      0.70     11419
#
# 0.5584226401648836

# %%
y_pred_proba
# Out:
# array([[0.49249005, 0.50750995],
#        [0.65674782, 0.34325218],
#        [0.9205632 , 0.0794368 ],
#        ...,
#        [0.54933614, 0.45066386],
#        [0.51643091, 0.48356909],
#        [0.52581736, 0.47418264]])

# %%
X1 = pd.get_dummies(X)
y1 = le.fit_transform(y)

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    # all the features that you want to examine
    for feature in features:
        # extract all the other features you will regress against
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        # extract r-squared from the fit
        r2 = LinearRegression().fit(X, y).score(X, y)                
        
        # calculate tolerance
        tolerance[feature] = 1 - r2
        # calculate VIF
        vif[feature] = 1/(tolerance[feature])
    # return VIF DataFrame
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})

# %%
X1.columns
# Out:
# Index(['appointment_dur_min', 'creation_to_start_hrs', 'confirm_to_start_hrs',
#        'patient_age', 'appointment_weekday_Friday',
#        'appointment_weekday_Monday', 'appointment_weekday_Saturday',
#        'appointment_weekday_Sunday', 'appointment_weekday_Thursday',
#        'appointment_weekday_Tuesday', 'appointment_weekday_Wednesday',
#        'recurring_patient_first', 'recurring_patient_recurrent',
#        'confirm_request_msg_no', 'confirm_request_msg_yes',
#        'patient_confirm_no', 'patient_confirm_yes', 'clinic_BASILICA',
#        'clinic_COAPA', 'clinic_CUAJIMALPA', 'clinic_DEL VALLE',
#        'clinic_DOCTORES', 'clinic_MARINA NACIONAL', 'clinic_TLALPAN',
#        'appointment_source_online', 'appointment_source_phone',
#        'appointment_date_update_no_update', 'appointment_date_update_update',
#        'patient_sex_F', 'patient_sex_M', 'rounded_start_times_07:00:00',
#        'rounded_start_times_08:00:00', 'rounded_start_times_09:00:00',
#        'rounded_start_times_10:00:00', 'rounded_start_times_11:00:00',
#        'rounded_start_times_12:00:00', 'rounded_start_times_13:00:00',
#        'rounded_start_times_14:00:00', 'rounded_start_times_15:00:00',
#        'rounded_start_times_16:00:00', 'rounded_start_times_17:00:00',
#        'rounded_start_times_18:00:00', 'rounded_start_times_19:00:00',
#        'rounded_start_times_20:00:00', 'month_April', 'month_August',
#        'month_December', 'month_February', 'month_January', 'month_July',
#        'month_June', 'month_March', 'month_May', 'month_November',
#        'month_October', 'month_September'],
#       dtype='object')

# %%
f = ['appointment_dur_min', 'creation_to_start_hrs', 'confirm_to_start_hrs',
       'patient_age', 'appointment_weekday_Friday',
       'appointment_weekday_Monday', 'appointment_weekday_Saturday',
       'appointment_weekday_Sunday', 'appointment_weekday_Thursday',
       'appointment_weekday_Tuesday', 'appointment_weekday_Wednesday',
       'recurring_patient_first', 'recurring_patient_recurrent',
       'confirm_request_msg_no', 'confirm_request_msg_yes',
       'patient_confirm_no', 'patient_confirm_yes', 'clinic_BASILICA',
       'clinic_COAPA', 'clinic_CUAJIMALPA', 'clinic_DEL VALLE',
       'clinic_DOCTORES', 'clinic_MARINA NACIONAL', 'clinic_TLALPAN',
       'appointment_source_online', 'appointment_source_phone',
       'appointment_date_update_no_update', 'appointment_date_update_update',
       'patient_sex_F', 'patient_sex_M', 'rounded_start_times_07:00:00',
       'rounded_start_times_08:00:00', 'rounded_start_times_09:00:00',
       'rounded_start_times_10:00:00', 'rounded_start_times_11:00:00',
       'rounded_start_times_12:00:00', 'rounded_start_times_13:00:00',
       'rounded_start_times_14:00:00', 'rounded_start_times_15:00:00',
       'rounded_start_times_16:00:00', 'rounded_start_times_17:00:00',
       'rounded_start_times_18:00:00', 'rounded_start_times_19:00:00',
       'rounded_start_times_20:00:00', 'month_April', 'month_August',
       'month_December', 'month_February', 'month_January', 'month_July',
       'month_June', 'month_March', 'month_May', 'month_November',
       'month_October', 'month_September']

# %%
calculate_vif(df=X1, features=f)
# Out:
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
# /var/folders/bn/w8nn2_c95217s6fm9n2llrqm0000gn/T/ipykernel_31957/727383610.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   vif[feature] = 1/(tolerance[feature])
#                                         VIF  Tolerance
# appointment_dur_min                1.039547   0.961958
# creation_to_start_hrs              1.235599   0.809324
# confirm_to_start_hrs               1.029169   0.971658
# patient_age                        1.016509   0.983759
# appointment_weekday_Friday              inf   0.000000
# appointment_weekday_Monday              inf   0.000000
# appointment_weekday_Saturday            inf   0.000000
# appointment_weekday_Sunday              inf   0.000000
# appointment_weekday_Thursday            inf   0.000000
# appointment_weekday_Tuesday             inf   0.000000
# appointment_weekday_Wednesday           inf   0.000000
# recurring_patient_first                 inf   0.000000
# recurring_patient_recurrent             inf   0.000000
# confirm_request_msg_no                  inf   0.000000
# confirm_request_msg_yes                 inf   0.000000
# patient_confirm_no                      inf   0.000000
# patient_confirm_yes                     inf   0.000000
# clinic_BASILICA                         inf   0.000000
# clinic_COAPA                            inf   0.000000
# clinic_CUAJIMALPA                       inf   0.000000
# clinic_DEL VALLE                        inf   0.000000
# clinic_DOCTORES                         inf   0.000000
# clinic_MARINA NACIONAL                  inf   0.000000
# clinic_TLALPAN                          inf   0.000000
# appointment_source_online               inf   0.000000
# appointment_source_phone                inf   0.000000
# appointment_date_update_no_update       inf   0.000000
# appointment_date_update_update          inf   0.000000
# patient_sex_F                           inf   0.000000
# patient_sex_M                           inf   0.000000
# rounded_start_times_07:00:00            inf   0.000000
# rounded_start_times_08:00:00            inf   0.000000
# rounded_start_times_09:00:00            inf   0.000000
# rounded_start_times_10:00:00            inf   0.000000
# rounded_start_times_11:00:00            inf   0.000000
# rounded_start_times_12:00:00            inf   0.000000
# rounded_start_times_13:00:00            inf   0.000000
# rounded_start_times_14:00:00            inf   0.000000
# rounded_start_times_15:00:00            inf   0.000000
# rounded_start_times_16:00:00            inf   0.000000
# rounded_start_times_17:00:00            inf   0.000000
# rounded_start_times_18:00:00            inf   0.000000
# rounded_start_times_19:00:00            inf   0.000000
# rounded_start_times_20:00:00            inf   0.000000
# month_April                             inf   0.000000
# month_August                            inf   0.000000
# month_December                          inf   0.000000
# month_February                          inf   0.000000
# month_January                           inf   0.000000
# month_July                              inf   0.000000
# month_June                              inf   0.000000
# month_March                             inf   0.000000
# month_May                               inf   0.000000
# month_November                          inf   0.000000
# month_October                           inf   0.000000
# month_September                         inf   0.000000
