# %% [markdown]
# # EDA | Problem exploration
# ---
# ---

# %% [markdown]
# # Imports

# %% [markdown]
# #### Standard library imports

# %%
import sys
sys.path.append("../../")

# %% [markdown]
# #### Third party imports

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### Local application imports

# %%
# %load_ext autoreload
# %autoreload 2

from pkg_dir.config import *
from pkg_dir.src.utils import *
from pkg_dir.src.functions import *
from pkg_dir.src.parameters import *

# %% [markdown]
# # Extracting data

# %%
## Function parameters
db_crds = 'pc_db_prod'
sql_files_path = '../../pkg_dir/sql/'
sql_script = 'appointments.sql'
sql_params = sql_params_appointments

# %%
dfx = sql_to_df(db_crds, sql_files_path, sql_script, sql_params)

# %% [markdown]
# # Manipulating data

# %%
## Reference to simplify labels in appointment status
values_map = {
    
    'COMPLETADA': 'completed',
    'SALA_ESPERA': 'completed',
    'CONSULTA': 'completed',
    'CONFIRMADO_PAGO': 'completed',

    'NO_PRESENTO': 'no_show',
    'MENSAJE_DEJADO': 'no_show',
    'NO_CONFIRMADO': 'no_show',
    'CONFIRMADO': 'no_show',
    'LLEGA_TARDE_ESPERA': 'no_show',
    'REAGENDAR': 'no_show',
    
}

# %%
## Mapping values according to reference
dfx['appointment_status_simple'] = dfx['appointment_status'].map(values_map).fillna(dfx['appointment_status'])

# %%
dfx
# Out:
#          appointment_id appointment_date appointment_start_time  \
# 0       2023000581549         2023-11-15                  14:00
# 1       2023000854685         2023-11-14                  16:00
# 2       2023001165360         2023-11-15                  10:30
# 3       2023000999514         2023-11-13                  11:30
# 4       2023000648833         2023-11-22                  07:30
# ...                 ...              ...                    ...
# 163561  2023001079843         2023-11-16                  18:00
# 163562  2022950161            2023-11-24                  10:30
# 163563  2023000485484         2023-11-13                  11:30
# 163564  2023144299            2023-11-15                  08:00
# 163565  2022988840            2023-11-13                  11:30
#
#        appointment_end_time appointment_creation appointment_status  \
# 0                     14:30  12/11/2023 12:54:18        NO_PRESENTO
# 1                     16:30  12/11/2023 15:51:52         COMPLETADA
# 2                     11:00  12/11/2023 17:02:45         COMPLETADA
# 3                     12:00  13/11/2023 07:15:22        NO_PRESENTO
# 4                     08:00  13/11/2023 09:11:24         COMPLETADA
# ...                     ...                  ...                ...
# 163561                18:30  11/11/2023 08:40:32         COMPLETADA
# 163562                11:00  11/11/2023 09:04:35         COMPLETADA
# 163563                12:00  11/11/2023 12:11:15         COMPLETADA
# 163564                08:30  11/11/2023 12:25:55         COMPLETADA
# 163565                12:00  11/11/2023 17:50:52         COMPLETADA
#
#                                         doctor     medical_specialty  \
# 0           DR.  Fernando Iván Vergara  Orduña           CARDIOLOGIA
# 1         DRA KARLA VANESSA RODRIGUEZ  JIMENEZ            NEUROLOGIA
# 2                 DRA ABIGAIL GONZALEZ MORALES          DERMATOLOGIA
# 3                   DRA NAYANSI CABRERA GARCIA           GINECOLOGIA
# 4             DRA Perla Lourdes  Díaz  Aguirre            ANGIOLOGIA
# ...                                        ...                   ...
# 163561     DR. JAIR ALEXANDER  QUINTERO PANUCO           CARDIOLOGIA
# 163562                   Mariana  Sarao Pineda          DERMATOLOGIA
# 163563        DR. PAOLA MARLENE GONZALEZ SOLIS  OTORRINOLARINGOLOGIA
# 163564        DR. DANIEL GEOVANI VASQUEZ LOPEZ          REUMATOLOGIA
# 163565  DRA JUANA GUADALUPE CABALLERO MARTINEZ           GINECOLOGIA
#
#                  clinic  patient_id patient_birth_date  \
# 0            MONTEVIDEO       92586         1953-11-28
# 1             DEL VALLE      272735         1938-01-28
# 2              DOCTORES      104330         1999-02-22
# 3              DOCTORES      272779         2003-12-10
# 4              BASILICA      272826         1956-10-07
# ...                 ...         ...                ...
# 163561  MARINA NACIONAL      272512         1964-08-21
# 163562  MARINA NACIONAL      272519         2011-10-20
# 163563          TLALPAN      272594         2009-09-03
# 163564         BASILICA      122176         1974-07-12
# 163565  MARINA NACIONAL      272652         2005-07-01
#
#        appointment_status_simple
# 0                        no_show
# 1                      completed
# 2                      completed
# 3                        no_show
# 4                      completed
# ...                          ...
# 163561                 completed
# 163562                 completed
# 163563                 completed
# 163564                 completed
# 163565                 completed
#
# [163566 rows x 12 columns]

# %%
df = dfx.head(10)

# %%
## Function parameters
db_crds = 'aws_db'
sql_files_path = '../../pkg_dir/sql/'
sql_script = 'aws_test.sql'

# %%
df
# Out:
#     appointment_id appointment_date appointment_start_time  \
# 0  2023000581549         2023-11-15                  14:00
# 1  2023000854685         2023-11-14                  16:00
# 2  2023001165360         2023-11-15                  10:30
# 3  2023000999514         2023-11-13                  11:30
# 4  2023000648833         2023-11-22                  07:30
# 5  2023001186934         2023-11-20                  12:10
# 6  2023001043445         2023-11-13                  11:30
# 7  2023000887515         2023-11-22                  17:30
# 8  2023001040935         2023-11-13                  18:00
# 9  2023000446422         2023-11-14                  10:00
#
#   appointment_end_time appointment_creation appointment_status  \
# 0                14:30  12/11/2023 12:54:18        NO_PRESENTO
# 1                16:30  12/11/2023 15:51:52         COMPLETADA
# 2                11:00  12/11/2023 17:02:45         COMPLETADA
# 3                12:00  13/11/2023 07:15:22        NO_PRESENTO
# 4                08:00  13/11/2023 09:11:24         COMPLETADA
# 5                12:50  13/11/2023 09:33:12         COMPLETADA
# 6                12:00  13/11/2023 09:51:39         COMPLETADA
# 7                18:00  13/11/2023 10:04:46           CONSULTA
# 8                18:30  13/11/2023 10:23:26           CONSULTA
# 9                11:00  13/11/2023 10:30:17         COMPLETADA
#
#                                   doctor  medical_specialty      clinic  \
# 0     DR.  Fernando Iván Vergara  Orduña        CARDIOLOGIA  MONTEVIDEO
# 1   DRA KARLA VANESSA RODRIGUEZ  JIMENEZ         NEUROLOGIA   DEL VALLE
# 2           DRA ABIGAIL GONZALEZ MORALES       DERMATOLOGIA    DOCTORES
# 3             DRA NAYANSI CABRERA GARCIA        GINECOLOGIA    DOCTORES
# 4       DRA Perla Lourdes  Díaz  Aguirre         ANGIOLOGIA    BASILICA
# 5          DRA LUZ MARIA  PINEDA CENTENO         NEUROLOGIA     TLALPAN
# 6         DR. FRANCISCO ALVARADO BELTRAN          ORTOPEDIA    DOCTORES
# 7          DR. OMAR ANTONY GOMEZ MORALES        Ultrasonido   DEL VALLE
# 8  DR. CARLOS ANDRES CAMPOVERDE ESPINOZA  GASTROENTEROLOGIA    DOCTORES
# 9       DR. Christopher Davalos Carbajal           UROLOGIA    BASILICA
#
#    patient_id patient_birth_date appointment_status_simple
# 0       92586         1953-11-28                   no_show
# 1      272735         1938-01-28                 completed
# 2      104330         1999-02-22                 completed
# 3      272779         2003-12-10                   no_show
# 4      272826         1956-10-07                 completed
# 5      215593         1958-10-28                 completed
# 6      272857         1968-07-09                 completed
# 7      272771         1993-12-08                 completed
# 8      269388         1995-12-31                 completed
# 9      236167         1965-07-27                 completed

# %%
db_crds
# Out:
# 'aws_db'

# %%
conn = database_conection(db_crds)
cursor = conn.cursor()

# %%
cursor.execute("DROP TABLE IF EXISTS raw")

# %%
sql_1 = '''CREATE TABLE IF NOT EXISTS raw (
   appointment_id varchar(255),
   appointment_date varchar(255),
   appointment_start_time varchar(255),
   appointment_end_time varchar(255),
   appointment_creation varchar(255),
   appointment_status varchar(255),
   doctor varchar(255),
   medical_specialty varchar(255),
   clinic varchar(255),
   patient_id int,
   patient_birth_date varchar(255),
   appointment_status_simple varchar(255)
)'''

# %%
cursor.execute(sql_1)

# %%
insert_query = '''INSERT INTO raw (
   appointment_id,
   appointment_date,
   appointment_start_time,
   appointment_end_time,
   appointment_creation,
   appointment_status,
   doctor,
   medical_specialty,
   clinic,
   patient_id,
   patient_birth_date,
   appointment_status_simple) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

# %%
cursor.executemany(insert_query, df.values)

# %%
cursor.close()
conn.commit()

# %%
conn = database_conection(db_crds)
cursor = conn.cursor()

# %%
select_query = '''SELECT * FROM raw'''

# %%
cursor.execute(select_query)

# %%
return_df = pd.DataFrame(cursor.fetchall())

# %%
return_df
# Out:
#                 0           1      2      3                    4   \
# 0  2023000581549    2023-11-15  14:00  14:30  12/11/2023 12:54:18
# 1  2023000854685    2023-11-14  16:00  16:30  12/11/2023 15:51:52
# 2  2023001165360    2023-11-15  10:30  11:00  12/11/2023 17:02:45
# 3  2023000999514    2023-11-13  11:30  12:00  13/11/2023 07:15:22
# 4  2023000648833    2023-11-22  07:30  08:00  13/11/2023 09:11:24
# 5  2023001186934    2023-11-20  12:10  12:50  13/11/2023 09:33:12
# 6  2023001043445    2023-11-13  11:30  12:00  13/11/2023 09:51:39
# 7  2023000887515    2023-11-22  17:30  18:00  13/11/2023 10:04:46
# 8  2023001040935    2023-11-13  18:00  18:30  13/11/2023 10:23:26
# 9  2023000446422    2023-11-14  10:00  11:00  13/11/2023 10:30:17
#
#             5                                      6                  7   \
# 0  NO_PRESENTO     DR.  Fernando Iván Vergara  Orduña        CARDIOLOGIA
# 1   COMPLETADA   DRA KARLA VANESSA RODRIGUEZ  JIMENEZ         NEUROLOGIA
# 2   COMPLETADA           DRA ABIGAIL GONZALEZ MORALES       DERMATOLOGIA
# 3  NO_PRESENTO             DRA NAYANSI CABRERA GARCIA        GINECOLOGIA
# 4   COMPLETADA       DRA Perla Lourdes  Díaz  Aguirre         ANGIOLOGIA
# 5   COMPLETADA          DRA LUZ MARIA  PINEDA CENTENO         NEUROLOGIA
# 6   COMPLETADA         DR. FRANCISCO ALVARADO BELTRAN          ORTOPEDIA
# 7     CONSULTA          DR. OMAR ANTONY GOMEZ MORALES        Ultrasonido
# 8     CONSULTA  DR. CARLOS ANDRES CAMPOVERDE ESPINOZA  GASTROENTEROLOGIA
# 9   COMPLETADA       DR. Christopher Davalos Carbajal           UROLOGIA
#
#            8       9           10         11
# 0  MONTEVIDEO   92586  1953-11-28    no_show
# 1   DEL VALLE  272735  1938-01-28  completed
# 2    DOCTORES  104330  1999-02-22  completed
# 3    DOCTORES  272779  2003-12-10    no_show
# 4    BASILICA  272826  1956-10-07  completed
# 5     TLALPAN  215593  1958-10-28  completed
# 6    DOCTORES  272857  1968-07-09  completed
# 7   DEL VALLE  272771  1993-12-08  completed
# 8    DOCTORES  269388  1995-12-31  completed
# 9    BASILICA  236167  1965-07-27  completed
